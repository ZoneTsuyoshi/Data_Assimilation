# %% [markdown]
# # 多変量に対応できる粒子フィルタ

# %% [markdown]
# 参照：https://github.com/matsuken92/Qiita_Contents/blob/master/particle_filter/particle_filter_class.ipynb <br>
# 参照：https://qiita.com/kenmatsu4/items/c5232b1499dfd00e877d <br>
# 参照：https://qiita.com/ryskiwt/items/a7c0b1b6c14ed5ccefca <br>
# 参照：http://business.nikkeibp.co.jp/atclbdt/15/recipe/102500014/

# %%
import numpy as np
import numpy.random as rd
import pandas as pd

import matplotlib
from matplotlib import font_manager
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="muted", color_codes=True)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_csv("./data/homesurvey2015.csv", header = 0)
df = df.iloc[:,2:]
df[1:10]
#df.columns = ["data"]
#df = df.astype(float)
# Out:
#    cabbage  bamboo   pork
# 1    -1.23   -0.38   0.30
# 2     3.60    3.23  11.38
# 3    -0.44   -1.82  10.21
# 4    -1.66    0.91 -27.25
# 5     0.56   -2.00  15.37
# 6    -0.19    0.88  -9.28
# 7    -0.03    3.06  -0.28
# 8    -0.07   -1.36  -4.57
# 9     3.33    3.57  20.51

# %%
df.plot(figsize = (12,4))
plt.title("Test Data")
